# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the CSV file into a DataFrame
Aviation_df = pd.read_csv('Aviation_Data.csv', low_memory=False)

# %% [markdown]
# ### First i check what the data entails ###

# %%
Aviation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
Aviation_df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
Aviation_df.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                   object
# Longitude                  object
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.flight          object
# Air.carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# ...

# %%
Aviation_df.shape
# Out:
# (90348, 31)

# %%
Aviation_df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %% [markdown]
# ### I started with the cleaning the data ###

# %%
Aviation_df.columns = Aviation_df.columns.str.replace('.', '_', regex=False)

# %%
Aviation_df.columns
# Out:
# Index(['Event_Id', 'Investigation_Type', 'Accident_Number', 'Event_Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport_Code',
#        'Airport_Name', 'Injury_Severity', 'Aircraft_damage',
#        'Aircraft_Category', 'Registration_Number', 'Make', 'Model',
#        'Amateur_Built', 'Number_of_Engines', 'Engine_Type', 'FAR_Description',
#        'Schedule', 'Purpose_of_flight', 'Air_carrier', 'Total_Fatal_Injuries',
#        'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured',
#        'Weather_Condition', 'Broad_phase_of_flight', 'Report_Status',
#        'Publication_Date'],
#       dtype='object')

# %%
# Convert `Event.Date` and `Publication.Date` to datetime
Aviation_df['Event_Date'] = pd.to_datetime(Aviation_df['Event_Date'], errors='coerce')
Aviation_df['Publication_Date'] = pd.to_datetime(Aviation_df['Publication_Date'], format='%d-%m-%Y', errors='coerce')

# %%
# Convert `Latitude` and `Longitude` to numeric, coercing errors to NaN
Aviation_df['Latitude'] = pd.to_numeric(Aviation_df['Latitude'], errors='coerce')
Aviation_df['Longitude'] = pd.to_numeric(Aviation_df['Longitude'], errors='coerce')

# %%
Aviation_df.head()
# Out:
#          Event_Id Investigation_Type Accident_Number Event_Date  \
# 0  20001218X45444           Accident      SEA87LA080 1948-10-24
# 1  20001218X45447           Accident      LAX94LA336 1962-07-19
# 2  20061025X01555           Accident      NYC07LA005 1974-08-30
# 3  20001218X45448           Accident      LAX96LA321 1977-06-19
# 4  20041105X01764           Accident      CHI79FA064 1979-08-02
#
#           Location        Country   Latitude  Longitude Airport_Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport_Name  ... Purpose_of_flight Air_carrier Total_Fatal_Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# Fill missing numerical columns with the median
numerical_cols = ['Number_of_Engines', 'Total_Fatal_Injuries', 'Total_Serious_Injuries', 'Total_Minor_Injuries', 'Total_Uninjured']
for col in numerical_cols:
    if col in Aviation_df.columns:
        Aviation_df[col] = Aviation_df[col].fillna(Aviation_df[col].median())

# %%
# Fill missing categorical columns with the mode
categorical_cols = [
    'Event_Id', 'Accident_Number', 'Location', 'Country', 'Airport_Code',
    'Airport_Name', 'Injury_Severity', 'Aircraft_damage', 'Aircraft_Category',
    'Registration_Number', 'Make', 'Model', 'Amateur_Built', 'Engine_Type',
    'FAR_Description', 'Purpose_of_flight', 'Weather_Condition',
    'Broad_phase_of_flight', 'Report_Status'
]
for col in categorical_cols:
    if col in Aviation_df.columns:
        Aviation_df[col] = Aviation_df[col].fillna(Aviation_df[col].mode()[0])

# %%
# Fill missing Date columns with backfill
date_cols = ['Event_Date', 'Publication_Date']
for col in date_cols:
    if col in Aviation_df.columns:
        Aviation_df[col] = Aviation_df[col].bfill()

# %%
Aviation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event_Id                90348 non-null  object
#  1   Investigation_Type      90348 non-null  object
#  2   Accident_Number         90348 non-null  object
#  3   Event_Date              90348 non-null  datetime64[ns]
#  4   Location                90348 non-null  object
#  5   Country                 90348 non-null  object
#  6   Latitude                11986 non-null  float64
#  7   Longitude               11974 non-null  float64
#  8   Airport_Code            90348 non-null  object
#  9   Airport_Name            90348 non-null  object
#  10  Injury_Severity         90348 non-null  object
#  11  Aircraft_damage         90348 non-null  object
#  12  Aircraft_Category       90348 non-null  object
#  13  Registration_Number     90348 non-null  object
# ...

# %%
#check for duplicates
Aviation_df.duplicated().sum()
# Out:
# 123

# %%
#check the actual duplicateee rows
Aviation_df[Aviation_df.duplicated()]
# Out:
#              Event_Id Investigation_Type Accident_Number Event_Date  \
# 64593  20001212X19172         25-09-2020      CEN22FA424 2008-05-24
# 69897  20001212X19172         25-09-2020      CEN22FA424 2011-04-23
# 72601  20001212X19172         25-09-2020      CEN22FA424 2012-08-31
# 72673  20001212X19172         25-09-2020      CEN22FA424 2012-09-08
# 72682  20001212X19172         25-09-2020      CEN22FA424 2012-09-09
# ...               ...                ...             ...        ...
# 88724  20001212X19172         22-06-2022      CEN22FA424 2022-02-18
# 88788  20001212X19172         05-07-2022      CEN22FA424 2022-03-02
# 88908  20001212X19172         05-07-2022      CEN22FA424 2022-03-26
# 88965  20001212X19172         13-10-2022      CEN22FA424 2022-04-05
# 89036  20001212X19172         20-07-2022      CEN22FA424 2022-04-17
#
#             Location        Country  Latitude  Longitude Airport_Code  \
# 64593  ANCHORAGE, AK  United States       NaN        NaN         NONE
# ...

# %%
#remove duplicates
Aviation_df.drop_duplicates(inplace=True)

# %%
Aviation_df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(Aviation_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
missing_percent = Aviation_df.isnull().mean().sort_values(ascending=False) * 100
missing_percent
# Out:
# Longitude                 86.728734
# Latitude                  86.715434
# Schedule                  86.054863
# Air_carrier               81.548351
# Event_Id                   0.000000
# Number_of_Engines          0.000000
# Report_Status              0.000000
# Broad_phase_of_flight      0.000000
# Weather_Condition          0.000000
# Total_Uninjured            0.000000
# Total_Minor_Injuries       0.000000
# Total_Serious_Injuries     0.000000
# Total_Fatal_Injuries       0.000000
# Purpose_of_flight          0.000000
# FAR_Description            0.000000
# Engine_Type                0.000000
# Model                      0.000000
# Amateur_Built              0.000000
# Investigation_Type         0.000000
# Make                       0.000000
# Registration_Number        0.000000
# Aircraft_Category          0.000000
# Aircraft_damage            0.000000
# Injury_Severity            0.000000
# Airport_Name               0.000000
# Airport_Code               0.000000
# ...

# %%
# Drop columns with more than 80% missing values

missing_percentage = Aviation_df.isnull().mean() * 100

columns_to_drop = missing_percentage[missing_percentage > 80].index.tolist()
Aviation_df_cleaned = Aviation_df.drop(columns=columns_to_drop)

# %%
Aviation_df.shape
# Out:
# (90225, 31)

# %% [markdown]
# ##  Aviation Accident Data Analysis – Problem Statements
#
# This analysis explores aviation accident data to identify trends, patterns, and potential safety gaps in global air travel. The goal is to answer key investigative questions and derive actionable insights. Below are the major problem statements guiding this project:
#
# ---
#
# ### 1. What are the trends in aviation accidents over time?
# - Are accidents increasing or decreasing over the years?
# - Which years recorded the highest number of accidents?
#
# ---
#
# ### 2. Which locations are most prone to aviation accidents?
# - Which countries or regions experience the most aviation incidents?
# - Can we identify hotspots or high-risk areas on the map?
#
# ---
#
# ### 3. What are the most common causes or phases of flight where accidents occur?
# - Do accidents mostly happen during takeoff, cruise, or landing?
# - Which weather conditions are linked to more incidents?
#
# ---
#
# ### 4. Are certain aircraft models or manufacturers involved in more accidents?
# - Which makes or models have the highest number of recorded accidents?
# - Do amateur-built or older aircraft have higher accident rates?
#
# ---
#
# ### 5. What are the most severe or fatal aviation accidents?
# - What is the death rate across different incidents?
# - Which accidents had the highest number of fatalities?
#
# ---
#
# ### 6. Are certain flight purposes or engine types more at risk?
# - Do commercial, private, or cargo flights experience more accidents?
# - How do single-engine vs multi-engine aircraft compare in safety?
#
#
# -These problem statements will guide our data cleaning, exploration, and visualization steps moving forward.

# %%
# Re-categorize 'Injury_Severity' for better readability
def categorize_injury_severity(severity):
    if 'Fatal' in severity:
        return 'Fatal'
    elif 'Serious' in severity:
        return 'Serious'
    elif 'Minor' in severity:
        return 'Minor'
    elif 'Non-Fatal' in severity:
        return 'Non-Fatal'
    elif 'Incident' in severity:
        return 'Incident'
    else:
        return 'Other/Unknown'

Aviation_df_cleaned['Injury_Severity_Categorized'] = Aviation_df_cleaned['Injury_Severity'].apply(categorize_injury_severity)

# %% [markdown]
# ### Let's first do descriptive analysis

# %%
print("Descriptive statistics for numerical columns:\n")
print(Aviation_df_cleaned.describe())
# Out:
# Descriptive statistics for numerical columns:
#
#                           Event_Date  Number_of_Engines  Total_Fatal_Injuries  \
# count                          90225       90225.000000          90225.000000
# mean   1999-12-25 23:29:32.887780608           1.134530              0.556398
# min              1948-10-24 00:00:00           0.000000              0.000000
# 25%              1989-03-17 00:00:00           1.000000              0.000000
# 50%              1998-10-15 00:00:00           1.000000              0.000000
# 75%              2010-01-18 00:00:00           1.000000              0.000000
# max              2022-12-29 00:00:00           8.000000            349.000000
# std                              NaN           0.429647              5.089008
#
#        Total_Serious_Injuries  Total_Minor_Injuries  Total_Uninjured  \
# count            90225.000000          90225.000000     90225.000000
# mean                 0.236930              0.304550         4.977966
# ...

# %%
print("\nDescriptive statistics for categorical columns:\n")
print(Aviation_df_cleaned.describe())
# Out:
# Descriptive statistics for categorical columns:
#
#                           Event_Date  Number_of_Engines  Total_Fatal_Injuries  \
# count                          90225       90225.000000          90225.000000
# mean   1999-12-25 23:29:32.887780608           1.134530              0.556398
# min              1948-10-24 00:00:00           0.000000              0.000000
# 25%              1989-03-17 00:00:00           1.000000              0.000000
# 50%              1998-10-15 00:00:00           1.000000              0.000000
# 75%              2010-01-18 00:00:00           1.000000              0.000000
# max              2022-12-29 00:00:00           8.000000            349.000000
# std                              NaN           0.429647              5.089008
#
#        Total_Serious_Injuries  Total_Minor_Injuries  Total_Uninjured  \
# count            90225.000000          90225.000000     90225.000000
# mean                 0.236930              0.304550         4.977966
# ...

# %%
#Analyzing specific categorical or numerical features in more detail.

# Relationship: Injury Severity (Categorized) by Aircraft Category
injury_by_category_categorized = Aviation_df_cleaned.groupby(['Aircraft_Category', 'Injury_Severity_Categorized']).size().unstack(fill_value=0)
print("\nInjury Severity (Categorized) by Aircraft Category:\n")
print(injury_by_category_categorized.to_markdown(numalign="left", stralign="left"))
# Out:
# Injury Severity (Categorized) by Aircraft Category:
#
# | Aircraft_Category   | Fatal   | Incident   | Minor   | Other/Unknown   | Serious   |
# |:--------------------|:--------|:-----------|:--------|:----------------|:----------|
# | Airplane            | 82942   | 2209       | 176     | 93              | 135       |
# | Balloon             | 225     | 0          | 0       | 0               | 6         |
# | Blimp               | 4       | 0          | 0       | 0               | 0         |
# | Glider              | 502     | 0          | 4       | 0               | 2         |
# | Gyrocraft           | 168     | 0          | 5       | 0               | 0         |
# | Helicopter          | 3370    | 9          | 33      | 3               | 25        |
# | Powered Parachute   | 89      | 0          | 0       | 0               | 2         |
# | Powered-Lift        | 4       | 1          | 0       | 0               | 0         |
# ...

# %%
# Relationship: Weather Condition and Injury Severity (Categorized)
injury_by_weather_categorized = Aviation_df_cleaned.groupby(['Weather_Condition', 'Injury_Severity_Categorized']).size().unstack(fill_value=0)
print("\nInjury Severity (Categorized) by Weather Condition:\n")
print(injury_by_weather_categorized.to_markdown(numalign="left", stralign="left"))
# Out:
# Injury Severity (Categorized) by Weather Condition:
#
# | Weather_Condition   | Fatal   | Incident   | Minor   | Other/Unknown   | Serious   |
# |:--------------------|:--------|:-----------|:--------|:----------------|:----------|
# | IMC                 | 5745    | 218        | 4       | 6               | 3         |
# | UNK                 | 730     | 100        | 0       | 26              | 0         |
# | Unk                 | 261     | 0          | 0       | 0               | 1         |
# | VMC                 | 80783   | 1901       | 214     | 64              | 169       |

# %%
# Average Fatalities by Aircraft Make (Top 10 Makes) - using original Total_Fatal_Injuries
avg_fatalities_by_make = Aviation_df_cleaned.groupby('Make')['Total_Fatal_Injuries'].mean().sort_values(ascending=False).head(10)
print("\nAverage Fatalities by Aircraft Make (Top 10):\n")
print(avg_fatalities_by_make)
# Out:
# Average Fatalities by Aircraft Make (Top 10):
#
# Make
# Tupolev               210.000000
# TUPOLEV                44.500000
# VIKING AIR LIMITED     23.000000
# Aviocar CASA           18.000000
# SUKHOI                 14.333333
# Mil Design Bureau      13.000000
# Mil                    13.000000
# ANTONOV                11.833333
# Embraer Aircraft       10.000000
# AIRvan                  9.000000
# Name: Total_Fatal_Injuries, dtype: float64

# %%
# Distribution of 'Number_of_Engines'
print("\nDistribution of Number of Engines:\n")
print(Aviation_df_cleaned['Number_of_Engines'].value_counts().sort_index())
# Out:
# Distribution of Number of Engines:
#
# Number_of_Engines
# 0.0     1226
# 1.0    77002
# 2.0    11079
# 3.0      483
# 4.0      431
# 6.0        1
# 8.0        3
# Name: count, dtype: int64

# %%
# Distribution of 'Engine_Type'
print("\nDistribution of Engine Type:\n")
print(Aviation_df_cleaned['Engine_Type'].value_counts())
# Out:
# Distribution of Engine Type:
#
# Engine_Type
# Reciprocating      77962
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# Hybrid Rocket          1
# UNK                    1
# Name: count, dtype: int64

# %%
# Visualizing temporal trends using Event_Date and Publication_Date.
import matplotlib.pyplot as plt
import altair as alt

# %%
# Extract the year like this:
Aviation_df_cleaned['Event_Date'] = pd.to_datetime(Aviation_df_cleaned['Event_Date'], errors='coerce')
Aviation_df_cleaned['Year'] = Aviation_df_cleaned['Event_Date'].dt.year

# %%
# Count the number of events per year
events_per_year = Aviation_df_cleaned['Year'].value_counts().sort_index().reset_index()
events_per_year.columns = ['Year', 'Event_Count']

# %%
# Plotting Events per Year (Event_Date)

#The chart below illustrates the number of aviation incidents and accidents based on their Event_Date.
chart_events = alt.Chart(events_per_year).mark_line(point=True).encode(
    x=alt.X('Year:O', axis=alt.Axis(title='Year')),
    y=alt.Y('Event_Count:Q', axis=alt.Axis(title='Number of Events')),
    tooltip=['Year', 'Event_Count']
).properties(
    title='Number of Aviation Events per Year (Event Date)'
).interactive()

chart_events
# Out:
# alt.Chart(...)

# %%
# Extract the year from 'Event_Date' and 'Publication_Date' for plotting
Aviation_df_cleaned['Event_Year'] = Aviation_df_cleaned['Event_Date'].dt.year
Aviation_df_cleaned['Publication_Year'] = Aviation_df_cleaned['Publication_Date'].dt.year

# %%
# Count the number of publications per year
publications_per_year = Aviation_df_cleaned['Publication_Year'].value_counts().sort_index().reset_index()
publications_per_year.columns = ['Year', 'Publication_Count']

# %%
# Plotting Publications per Year (Publication_Date)

#The chart below displays the number of aviation incident and accident reports based on their Publication_Date.

chart_publications = alt.Chart(publications_per_year).mark_line(point=True).encode(
    x=alt.X('Year:O', axis=alt.Axis(title='Year')),
    y=alt.Y('Publication_Count:Q', axis=alt.Axis(title='Number of Publications')),
    tooltip=['Year', 'Publication_Count']
).properties(
    title='Number of Aviation Reports Published per Year (Publication Date)'
).interactive()

chart_publications
# Out:
# alt.Chart(...)

# %% [markdown]
# ### What are the trends in aviation accidents over time? ###

# %%
# Extract the year like this:
Aviation_df_cleaned['Event_Date'] = pd.to_datetime(Aviation_df_cleaned['Event_Date'], errors='coerce')
Aviation_df_cleaned['Year'] = Aviation_df_cleaned['Event_Date'].dt.year

# %%
#Count and Plot Accidents Per Year
accidents_per_year = Aviation_df_cleaned['Year'].value_counts().sort_index()

total_accidents = accidents_per_year.sum()
print(f"Total number of accidents: {total_accidents}")
# Out:
# Total number of accidents: 90225

# %%
accidents_per_year.shape
# Out:
# (47,)

# %%
print(f"Total number of accidents: {accidents_per_year}")
# Out:
# Total number of accidents: Year
# 1948       1
# 1962       1
# 1974       1
# 1977       1
# 1979       2
# 1981       1
# 1982    3593
# 1983    3556
# 1984    3457
# 1985    3096
# 1986    2880
# 1987    2828
# 1988    2730
# 1989    2544
# 1990    2518
# 1991    2462
# 1992    2355
# 1993    2313
# 1994    2257
# 1995    2309
# 1996    2187
# 1997    2148
# 1998    2226
# 1999    2209
# 2000    2220
# 2001    2063
# 2002    2020
# 2003    2085
# 2004    1952
# 2005    2031
# 2006    1851
# 2007    2016
# 2008    1912
# 2009    1783
# 2010    1793
# 2011    1871
# 2012    1894
# 2013    1651
# 2014    1646
# 2015    1651
# 2016    1738
# 2017    1753
# 2018    1860
# 2019    1766
# 2020    1539
# 2021    1655
# 2022    1800
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 6))
sns.lineplot(x=accidents_per_year.index, y=accidents_per_year.values, marker='o')
plt.title('Trend of Aviation Accidents Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.grid(True)
plt.show()

# %% [markdown]
# ###  What are the most common types and causes of aviation accidents, and when during a flight are they most likely to occur? ###

# %%
Aviation_df_cleaned.columns
# Out:
# Index(['Event_Id', 'Investigation_Type', 'Accident_Number', 'Event_Date',
#        'Location', 'Country', 'Airport_Code', 'Airport_Name',
#        'Injury_Severity', 'Aircraft_damage', 'Aircraft_Category',
#        'Registration_Number', 'Make', 'Model', 'Amateur_Built',
#        'Number_of_Engines', 'Engine_Type', 'FAR_Description',
#        'Purpose_of_flight', 'Total_Fatal_Injuries', 'Total_Serious_Injuries',
#        'Total_Minor_Injuries', 'Total_Uninjured', 'Weather_Condition',
#        'Broad_phase_of_flight', 'Report_Status', 'Publication_Date',
#        'Injury_Severity_Categorized', 'Year'],
#       dtype='object')

# %%
# Accident count by phase of flight
print("\n Accidents by Flight Phase:\n")
print(Aviation_df_cleaned['Broad_phase_of_flight'].value_counts(dropna=False))
# Out:
#  Accidents by Flight Phase:
#
# Broad_phase_of_flight
# Landing        43929
# Takeoff        12493
# Cruise         10269
# Maneuvering     8144
# Approach        6546
# Climb           2034
# Taxi            1958
# Descent         1887
# Go-around       1353
# Standing         945
# Unknown          548
# Other            119
# Name: count, dtype: int64

# %% [markdown]
# ### Visualize

# %%
flight_phase_counts = (
    Aviation_df_cleaned['Broad_phase_of_flight']
    .value_counts()
    .sort_values(ascending=False)
)


plt.figure(figsize=(12, 6))
sns.barplot(
    x=flight_phase_counts.values,
    y=flight_phase_counts.index,
    hue=flight_phase_counts.index,  # Assign y variable to hue
    palette='coolwarm',
    dodge=False,
    legend=False
)
plt.title('Accidents by Flight Phase')
plt.xlabel('Number of Accidents')
plt.ylabel('Flight Phase')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Weather condition during accidents
print("\n Accidents by Weather Condition:\n")
print(Aviation_df_cleaned['Weather_Condition'].value_counts(dropna=False))
# Out:
#  Accidents by Weather Condition:
#
# Weather_Condition
# VMC    83131
# IMC     5976
# UNK      856
# Unk      262
# Name: count, dtype: int64

# %%
#Group by Year and Weather_Condition
accidents_by_weather = (
    Aviation_df_cleaned
    .groupby(['Year', 'Weather_Condition'])
    .size()
    .unstack(fill_value=0)  # Turns Weather_Condition values into columns
    .sort_index()
)

# %% [markdown]
# ### Visualize

# %%
# Plot All Accidents, IMC, and VMC Over Time
plt.figure(figsize=(14, 7))

# Plot each line
sns.lineplot(x=accidents_by_weather.index, y=accidents_by_weather.sum(axis=1), label='Total Accidents', marker='o', linewidth=2)
if 'IMC' in accidents_by_weather.columns:
    sns.lineplot(x=accidents_by_weather.index, y=accidents_by_weather['IMC'], label='IMC Accidents', marker='o')
if 'VMC' in accidents_by_weather.columns:
    sns.lineplot(x=accidents_by_weather.index, y=accidents_by_weather['VMC'], label='VMC Accidents', marker='o')

# Formatting
plt.title('Aviation Accident Trends by Weather Condition (IMC vs VMC)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.legend()
plt.grid(True)

# Annotate global events
highlight_events = {
    2001: "9/11 Attacks",
    2008: "Global Financial Crisis",
    2020: "COVID-19"
}
for year, label in highlight_events.items():
    if year in accidents_by_weather.index:
        plt.axvline(x=year, color='gray', linestyle='--', alpha=0.5)
        plt.text(year + 0.2, plt.ylim()[1]*0.85, label, rotation=90, color='gray')

plt.tight_layout()
plt.show()

# %%
 # Accident severity distribution
print("\n Accident Severity:\n")

severity_counts = Aviation_df_cleaned['Injury_Severity_Categorized'].value_counts()
print(severity_counts)
# Out:
#  Accident Severity:
#
# Injury_Severity_Categorized
# Fatal            87519
# Incident          2219
# Minor              218
# Serious            173
# Other/Unknown       96
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    x=severity_counts.index,
    y=severity_counts.values,
    palette='viridis',
    hue=severity_counts.index,  # Explicitly assign hue
    legend=False                # Turn off legend since it’s redundant here
)
plt.title('Accident Severity Distribution')
plt.xlabel('Severity Level')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Aircraft makes most involved in accidents
print("\n Top Aircraft Makes:\n")
top_makes = Aviation_df_cleaned['Make'].value_counts().head(10)
print(top_makes)
# Out:
#  Top Aircraft Makes:
#
# Make
# Cessna     23626
# Piper      12029
# CESSNA      4922
# Beech       4330
# PIPER       2841
# Bell        2134
# Boeing      1594
# BOEING      1151
# Grumman     1094
# Mooney      1092
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=top_makes.values,
    y=top_makes.index,
    palette='mako',
    hue=top_makes.index,
    legend=False
)
plt.title('Top 10 Aircraft Makes Involved in Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Aircraft Make')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#Purpose of flights that crashed
print("\n🎯 Purpose of Flight:\n")
purpose_counts = Aviation_df_cleaned['Purpose_of_flight'].value_counts()
print(purpose_counts)
# Out:
# 🎯 Purpose of Flight:
#
# Purpose_of_flight
# Personal                     56976
# Instructional                10601
# Unknown                       6802
# Aerial Application            4712
# Business                      4018
# Positioning                   1646
# Other Work Use                1264
# Ferry                          812
# Aerial Observation             794
# Public Aircraft                720
# Executive/corporate            553
# Flight Test                    405
# Skydiving                      182
# External Load                  123
# Public Aircraft - Federal      105
# Banner Tow                     101
# Air Race show                   99
# Public Aircraft - Local         74
# Public Aircraft - State         64
# Air Race/show                   59
# Glider Tow                      53
# Firefighting                    40
# Air Drop                        11
# ASHO                             6
# PUBS                             4
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=purpose_counts.values,
    y=purpose_counts.index,
    palette='flare',
    hue=purpose_counts.index,
    legend=False
)
plt.title('Top Purposes of Flight Involved in Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Purpose of Flight')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Which locations are most prone to aviation accidents?

# %%
# Most affected countries
print("\n Countries with Most Accidents:\n")
country_counts = Aviation_df_cleaned['Country'].value_counts().head(10)
country_counts
# Out:
#  Countries with Most Accidents:
# Country
# United States     83810
# Brazil              374
# Canada              359
# Mexico              358
# United Kingdom      344
# Australia           300
# France              236
# Spain               226
# Bahamas             216
# Germany             215
# Name: count, dtype: int64

# %% [markdown]
# ### Ploting

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=country_counts.values,
    y=country_counts.index,
    palette='rocket',
    hue=country_counts.index,
    legend=False
)
plt.title('Top 10 Countries with the Most Aviation Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Country')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
